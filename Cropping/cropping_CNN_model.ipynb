# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, AveragePooling2D, BatchNormalization
#import l2-norm pooling
from tensorflow.keras.layers import Lambda
from tensorflow.keras import backend as K


def l2_norm(x):
    x = x**2
    x = K.sum(x, axis=3, keepdims=True)
    x= K.sqrt(x)
    return x
l2_norm_pooling = Lambda(lambda x: l2_norm(x))
from tensorflow.keras.metrics import RootMeanSquaredError
# Out:
# WARNING:tensorflow:From d:\_projects\_for_customers\Nvzn_ML\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From d:\_projects\_for_customers\Nvzn_ML\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# preprocessing
def preprocess(img_path, show=False):
    image = cv2.imread(img_path)
    image = cv2.resize(image, (256, 256))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # find 200 keypoints with SIFT
    sift = cv2.SIFT_create(nfeatures=200, contrastThreshold=0.005)
    kp = sift.detect(image, None)
    if len(kp) < 200:
        kp += cv2.SIFT_create(nfeatures=len(kp)-200, contrastThreshold=0.0001).detect(image, None)
    if len(kp) > 200:
        kp = kp[:200]
    if show:
        print(len(kp))
        # show the keypoints
        image = cv2.drawKeypoints(image, kp, None)
        cv2.imshow('image', image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
    
    # cast to float32, normalize and reshape
    kp = np.array([k.pt for k in kp], dtype=np.float32)
    kp /= 255.0
    #kp = kp.reshape(1, 200, 2)
    return kp

# %%
print(preprocess('scrapped_images1/0_7.jpg', show=True))
# Out:
# 200
# [[0.1132782  0.0374416 ]
#  [0.9074974  0.73773307]
#  [0.3219107  0.84775263]
#  [0.80422735 0.36091012]
#  [0.80349237 0.57291746]
#  [0.3219107  0.84775263]
#  [0.3219107  0.84775263]
#  [0.80349237 0.57291746]
#  [0.80349237 0.57291746]
#  [0.9257316  0.07567762]
#  [0.31583455 0.44811073]
#  [0.9257316  0.07567762]
#  [0.78208923 0.24280223]
#  [0.9259598  0.7238679 ]
#  [0.36774865 0.07065852]
#  [0.06343682 0.9497703 ]
#  [0.06343682 0.9497703 ]
#  [0.06343682 0.9497703 ]
#  [0.7761342  0.5354224 ]
#  [0.3688654  0.4449142 ]
#  [0.3709435  0.23929033]
#  [0.76935726 0.3081576 ]
#  [0.76935726 0.3081576 ]
#  [0.93135977 0.14530882]
#  [0.9399474  0.929657  ]
#  [0.7441984  0.52816254]
#  [0.38188708 0.27087492]
#  [0.7441984  0.52816254]
#  [0.6859887  0.07070081]
#  [0.1132782  0.0374416 ]
#  [0.94659543 0.05097001]
#  [0.9522392  0.91778696]
#  [0.11412621 0.92937624]
#  [0.7306844  0.5507156 ]
#  [0.29836485 0.85146755]
#  [0.9730122  0.34126824]
#  [0.28782192 0.8427817 ]
#  [0.70770824 0.5372724 ]
#  [0.6998225  0.43552384]
#  [0.12648557 0.04658212]
#  [0.12698297 0.07060673]
#  [0.39215845 0.64076483]
#  [0.39215845 0.64076483]
#  [0.39247933 0.14796485]
#  [0.13014875 0.4345278 ]
#  [0.13199928 0.42868865]
#  [0.49207374 0.7016349 ]
#  [0.2728937  0.3190724 ]
#  [0.6898083  0.6883424 ]
#  [0.6898083  0.6883424 ]
#  [0.39782593 0.7482392 ]
#  [0.39782593 0.7482392 ]
#  [0.2728937  0.3190724 ]
#  [0.2728937  0.3190724 ]
#  [0.2728937  0.3190724 ]
#  [0.49830377 0.42003825]
#  [0.80977356 0.53389335]
#  [0.4857699  0.5668863 ]
#  [0.6838699  0.7993508 ]
#  [0.40547422 0.14813384]
#  [0.40571666 0.75504124]
#  [0.40571666 0.75504124]
#  [0.14413236 0.48642787]
#  [0.40577647 0.16933747]
#  [0.48095834 0.7536531 ]
#  [0.40577647 0.16933747]
#  [0.4078652  0.32196823]
#  [0.6838699  0.7993508 ]
#  [0.40990657 0.44369274]
#  [0.40990657 0.44369274]
#  [0.6723108  0.93083334]
#  [0.5015512  0.71007115]
#  [0.25192863 0.18226047]
#  [0.25192863 0.18226047]
#  [0.51257867 0.5246982 ]
#  [0.4172564  0.31031358]
#  [0.51257867 0.5246982 ]
#  [0.63863325 0.35796148]
#  [0.24612515 0.1370019 ]
#  [0.47038597 0.41380072]
#  [0.5162322  0.16844866]
#  [0.6341373  0.6355626 ]
#  [0.41987506 0.23178783]
#  [0.41987506 0.23178783]
#  [0.42152798 0.07029739]
#  [0.6341373  0.6355626 ]
#  [0.6341373  0.6355626 ]
#  [0.450277   0.4093631 ]
#  [0.62950164 0.4871904 ]
#  [0.52932173 0.31147084]
#  [0.62950164 0.4871904 ]
#  [0.5388707  0.23369123]
#  [0.2353136  0.07518493]
#  [0.43202937 0.547586  ]
#  [0.61688304 0.46296465]
#  [0.6159156  0.5947377 ]
#  [0.19271852 0.82801205]
#  [0.61543864 0.3660152 ]
#  [0.43713325 0.8291902 ]
#  [0.54934984 0.23007327]
#  [0.59540755 0.67363286]
#  [0.5945929  0.20725085]
#  [0.59347016 0.55908644]
#  [0.55303645 0.40088633]
#  [0.4525248  0.7108506 ]
#  [0.4525248  0.7108506 ]
#  [0.20768392 0.46016753]
#  [0.20768392 0.46016753]
#  [0.4449943  0.19392788]
#  [0.4449943  0.19392788]
#  [0.21209663 0.92736983]
#  [0.5751649  0.25665456]
#  [0.5563199  0.70544016]
#  [0.450277   0.4093631 ]
#  [0.450277   0.4093631 ]
#  [0.8983189  0.92987275]
#  [0.32936335 0.10665979]
#  [0.32936335 0.10665979]
#  [0.87052214 0.6192863 ]
#  [0.8537896  0.5150909 ]
#  [0.8537896  0.5150909 ]
#  [0.33100903 0.4099707 ]
#  [0.33100903 0.4099707 ]
#  [0.33297718 0.7071371 ]
#  [0.83558244 0.33357275]
#  [0.83558244 0.33357275]
#  [0.8270582  0.6330018 ]
#  [0.34092888 0.10479376]
#  [0.34262004 0.75081146]
#  [0.8175026  0.81006396]
#  [0.8125389  0.5475028 ]
#  [0.8125389  0.5475028 ]
#  [0.34421894 0.9309037 ]
#  [0.34443772 0.1566681 ]
#  [0.34443772 0.1566681 ]
#  [0.5123389  0.55607384]
#  [0.49841553 0.7556849 ]
#  [0.51384586 0.6729501 ]
#  [0.51384586 0.6729501 ]
#  [0.6348828  0.6476523 ]
#  [0.6348828  0.6476523 ]
#  [0.42268258 0.8118777 ]
#  [0.97462946 0.5057396 ]
#  [0.63266385 0.50495535]
#  [0.5112035  0.6237587 ]
#  [0.24959545 0.3227138 ]
#  [0.24959545 0.3227138 ]
#  [0.5109066  0.40930563]
#  [0.5109066  0.40930563]
#  [0.5904501  0.75137687]
#  [0.9207706  0.37419945]
#  [0.5109066  0.40930563]
#  [0.23645122 0.07108071]
#  [0.259616   0.68013585]
#  [0.259616   0.68013585]
#  [0.14866766 0.1050239 ]
#  [0.4851006  0.42613977]
#  [0.68482953 0.41045657]
#  [0.92388964 0.21522056]
#  [0.30373815 0.45981112]
#  [0.9489006  0.9468856 ]
#  [0.75498146 0.6404361 ]
#  [0.9642106  0.51564085]
#  [0.925733   0.49759066]
#  [0.29448777 0.22049929]
#  [0.4917502  0.7134685 ]
#  [0.75498146 0.6404361 ]
#  [0.92755634 0.76185673]
#  [0.7099528  0.75440264]
#  [0.34460387 0.07569961]
#  [0.13953926 0.25560418]
#  [0.13953926 0.25560418]
#  [0.4959724  0.48690352]
#  [0.4959724  0.48690352]
#  [0.4959724  0.48690352]
#  [0.46826628 0.4005428 ]
#  [0.46826628 0.4005428 ]
#  [0.7916808  0.20599224]
#  [0.4623839  0.63482213]
#  [0.4623839  0.63482213]
#  [0.65009046 0.42046523]
#  [0.65009046 0.42046523]
#  [0.9247978  0.5864697 ]
#  [0.60581094 0.5989053 ]
#  [0.26998204 0.739622  ]
#  [0.34698704 0.43585664]
#  [0.57675105 0.1390482 ]
#  [0.73834467 0.43382713]
#  [0.35499805 0.59766275]
#  [0.35499805 0.59766275]
#  [0.5924924  0.07581406]
#  [0.36076745 0.6257216 ]
#  [0.36076745 0.6257216 ]
#  [0.9228702  0.7121785 ]
#  [0.8112672  0.83695024]
#  [0.8112672  0.83695024]
#  [0.66886514 0.17714396]
#  [0.638211   0.07382278]
#  [0.7085889  0.7174034 ]
#  [0.49214447 0.5783264 ]]

# %%
#local imports
from local_package.Cropping import trim_to_edges
from local_package.Cropping import crop_with_perspective
#from local_package.ConvNN import preproces

# %%
#prepare a dataset for training the model
def prepare_dataset():
    directory = './scrapped_images1/'
    images = []
    label_values = []
    for file_name in os.listdir(directory):
        # 5-13, 18-20
        if all([not file_name.startswith(f'{str(i)}_') for i in range(5, 14)] + [not file_name.startswith(f'{str(i)}_') for i in range(18, 21)]):
            continue
        file_path = os.path.join(directory, file_name)
        try:
            image = cv2.imread(file_path)
            top_left, top_right, bottom_left, bottom_right = trim_to_edges(image, file_name)
            # normalize the points
            # top_left = [top_left[0] / image.shape[1]*255, top_left[1] / image.shape[0]*255]
            # top_right = [top_right[0] / image.shape[1]*255, top_right[1] / image.shape[0]*255]
            # bottom_left = [bottom_left[0] / image.shape[1]*255, bottom_left[1] / image.shape[0]*255]
            # bottom_right = [bottom_right[0] / image.shape[1]*255, bottom_right[1] / image.shape[0]*255]

            top_left = [top_left[0] / image.shape[1], top_left[1] / image.shape[0]]
            top_right = [top_right[0] / image.shape[1], top_right[1] / image.shape[0]]
            bottom_left = [bottom_left[0] / image.shape[1], bottom_left[1] / image.shape[0]]
            bottom_right = [bottom_right[0] / image.shape[1], bottom_right[1] / image.shape[0]]

            images.append(preprocess(file_path))
            label_values.append([top_left, top_right, bottom_left, bottom_right])
        except Exception as e:
            print(f"Exception for {file_name}:", e)
    return images, label_values

# %%
def preprocess(image):
    image = cv2.resize(image, (320, 320))
    # converto to 3 channel if gray or 4 channel
    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
    if image.shape[2] == 4:
        image = cv2.cvtColor(image, cv2.COLOR_BGRA2BGR)

    return image

# %%
#prepare a dataset for fine-tuning the u2net model
def u2net_prepare_dataset():
    directory = './Scraping_images/generated_with_coordinates(fixed_0)'
    images = []
    label_masks = []
    with open('./Scraping_images/generated_with_coordinates(fixed_0)/coordinates.txt', 'r') as f:
        lines = f.readlines()
        coord_dict = {}
        for line in lines:
            line = line.split()
            coord_dict[int(line[0].split('_')[1].split('.')[0])] = [float(x) for x in line[1:]]
            
        for file_name in os.listdir(directory):
            file_path = os.path.join(directory, file_name)
            try:
                #print(int(file_name.split('_')[1].split('.')[0]))
                #print(coord_dict[int(file_name.split('_')[1].split('.')[0])])
                image = cv2.imread(file_path)
                top_left_x, top_left_y, top_right_x, top_right_y, bottom_left_x, bottom_left_y, bottom_right_x, bottom_right_y = coord_dict[int(file_name.split('_')[1].split('.')[0])]
                top_left = [top_left_x, top_left_y] 
                top_right = [top_right_x, top_right_y]
                bottom_left = [bottom_left_x, bottom_left_y] if bottom_left_x < bottom_right_x else [bottom_right_x, bottom_right_y]
                bottom_right = [bottom_right_x, bottom_right_y] if bottom_left_x < bottom_right_x else [bottom_left_x, bottom_left_y]
                # normalize the points
                top_left = [top_left[0] / image.shape[1]*320, top_left[1] / image.shape[0]*320]
                top_right = [top_right[0] / image.shape[1]*320, top_right[1] / image.shape[0]*320]
                bottom_left = [bottom_left[0] / image.shape[1]*320, bottom_left[1] / image.shape[0]*320]
                bottom_right = [bottom_right[0] / image.shape[1]*320, bottom_right[1] / image.shape[0]*320]
                
                label_mask = np.zeros((320, 320, 1), dtype=np.uint8)
                label_mask = cv2.fillConvexPoly(label_mask, np.array([top_left, top_right, bottom_right, bottom_left], dtype=np.int32), 255)
                
                images.append(preprocess(image))
                label_masks.append(label_mask)
                
            except Exception as e:
                print(f"Exception for {file_name}:", e)
    return images, label_masks

# %%
u2net_images, u2net_label_masks = u2net_prepare_dataset()
# Out:
# Exception for coordinates.txt: list index out of range

# %%
print(len(u2net_images), len(u2net_label_masks))
# Out:
# 2789 2789

# %%
# save the dataset as images
for i, (img, mask) in enumerate(zip(u2net_images, u2net_label_masks)):
    cv2.imwrite(f'Cropping/U-2-Net/train_data/DUTS/DUTS-TR/DUTS-TR/im_aug/25_{i}.jpg', img)
    cv2.imwrite(f'Cropping/U-2-Net/train_data/DUTS/DUTS-TR/DUTS-TR/gt_aug/25_{i}.png', mask)

# %%
images, label_values = prepare_dataset()
# Out:
# Exception for 10_0.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_1.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_10.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_100.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_101.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_102.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_103.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_104.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_105.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_106.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_107.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_108.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_109.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_11.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_110.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_111.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_112.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_113.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_114.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_115.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_116.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_117.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_118.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_119.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_12.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_120.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_121.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_122.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_123.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_124.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_125.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_126.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_127.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_128.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_129.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_13.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_130.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_131.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_132.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_133.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_134.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_135.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_136.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_137.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_138.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_139.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_14.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_140.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_141.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_142.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_143.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_144.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_145.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_146.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_147.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_148.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_149.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_15.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_150.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_151.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_152.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_153.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_154.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_155.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_156.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_157.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_158.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_159.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_16.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_160.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_161.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_162.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_163.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_164.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_165.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_166.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_167.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_168.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_169.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_17.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_170.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_171.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_172.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_173.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_174.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_175.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_176.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_177.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_178.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_179.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_18.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_180.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_181.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_182.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_183.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_184.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_185.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_186.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_187.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_188.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_189.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_19.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_190.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_191.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_192.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_193.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_194.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_195.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_196.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_197.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_198.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_199.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_2.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_20.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_200.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_201.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_202.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_203.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_204.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_205.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_206.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_207.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_208.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_209.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_21.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_210.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_211.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_212.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_213.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_214.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_215.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_216.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_217.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_218.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_219.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_22.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_220.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_221.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_222.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_223.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_224.jpg: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Exception for 10_23.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_24.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_25.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_26.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_27.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_28.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_29.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_3.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_30.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_31.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_32.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_33.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_34.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_35.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_36.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_37.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_38.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_39.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_4.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_40.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_41.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_42.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_43.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_44.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_45.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_46.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_47.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_48.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_49.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_5.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_50.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_51.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_52.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_53.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_54.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_55.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_56.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_57.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_58.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_59.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_6.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_60.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_61.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_62.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_63.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_64.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_65.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_66.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_67.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_68.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_69.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_7.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_70.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_71.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_72.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_73.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_74.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_75.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_76.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_77.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_78.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_79.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_8.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_80.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_81.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_82.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_83.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_84.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_85.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_86.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_87.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_88.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_89.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_9.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_90.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_91.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_92.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_93.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_94.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_95.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 10_96.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# ...
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_56.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_57.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_58.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_59.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_6.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_60.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_61.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_62.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_63.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_64.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_65.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_66.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_67.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_68.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_69.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_7.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_70.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_71.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_72.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_73.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_74.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_75.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_76.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_77.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_78.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_79.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_8.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_80.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_81.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_82.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_83.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_84.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_85.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_86.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_87.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_88.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_89.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_9.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_90.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_91.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_92.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_93.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_94.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_95.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_96.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_97.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_98.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 13_99.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_0.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_10.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_100.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1000.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1001.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1002.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1003.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1004.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1005.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1006.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1007.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1008.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1009.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_101.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1010.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1011.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1012.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1013.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1014.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Exception for 18_1015.jpg: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 images, label_values = prepare_dataset()
#
# Cell In[4], line 12, in prepare_dataset()
#      10 file_path = os.path.join(directory, file_name)
#      11 try:
# ---> 12     image = cv2.imread(file_path)
#      13     top_left, top_right, bottom_left, bottom_right = trim_to_edges(image, file_name)
#      14     # normalize the points
#      15     # top_left = [top_left[0] / image.shape[1]*255, top_left[1] / image.shape[0]*255]
#      16     # top_right = [top_right[0] / image.shape[1]*255, top_right[1] / image.shape[0]*255]
#      17     # bottom_left = [bottom_left[0] / image.shape[1]*255, bottom_left[1] / image.shape[0]*255]
#      18     # bottom_right = [bottom_right[0] / image.shape[1]*255, bottom_right[1] / image.shape[0]*255]
#
# KeyboardInterrupt:

# %%
images1 = []
for img in images:
    points = []
    for point in img:
        points.append(point[0])
        points.append(point[1])
    images1.append(points)
print(images1[:10])
# Out:
# [[0.08965749, 0.16262488, 0.10964388, 0.48641077, 0.10991519, 0.6557058, 0.13135603, 0.21011873, 0.13135603, 0.21011873, 0.13199008, 0.7846878, 0.17263263, 0.25095648, 0.17263263, 0.25095648, 0.2177844, 0.29640305, 0.2177844, 0.29640305, 0.21789008, 0.18847257, 0.26287317, 0.38496637, 0.26291466, 0.33757666, 0.26291466, 0.33757666, 0.26630318, 0.6449963, 0.26630318, 0.6449963, 0.67171186, 0.59596294, 0.67171186, 0.59596294, 0.30072716, 0.648775, 0.30100578, 0.37459448, 0.30100578, 0.37459448, 0.4872577, 0.6488536, 0.6616981, 0.47102264, 0.92976946, 0.8033959, 0.6318425, 0.63853854, 0.38839474, 0.63811475, 0.31162575, 0.5633372, 0.62235856, 0.3450105, 0.49489132, 0.3422241, 0.62008286, 0.1786581, 0.32780567, 0.6493351, 0.3334319, 0.5322725, 0.3334319, 0.5322725, 0.5857795, 0.7724321, 0.57808834, 0.33797324, 0.57620907, 0.3420842, 0.3432632, 0.49857536, 0.3432632, 0.49857536, 0.3432632, 0.49857536, 0.5720435, 0.4485537, 0.34940434, 0.6483741, 0.5069478, 0.29335088, 0.56859654, 0.6483788, 0.56328976, 0.35218295, 0.56103796, 0.48842725, 0.36715186, 0.64909095, 0.55711466, 0.2604427, 0.5566241, 0.6484347, 0.54713315, 0.38665468, 0.38650578, 0.6476302, 0.5411477, 0.5194542, 0.5305018, 0.6475369, 0.53408104, 0.45711717, 0.5363081, 0.48427835, 0.8624596, 0.21369043, 0.8624596, 0.21369043, 0.85265106, 0.5019267, 0.8524991, 0.7737402, 0.8524991, 0.7737402, 0.8524705, 0.65574723, 0.85168296, 0.55553204, 0.8515462, 0.4636696, 0.8512415, 0.629762, 0.43017137, 0.33733237, 0.43030024, 0.6423872, 0.83414155, 0.75518435, 0.83414155, 0.75518435, 0.8254048, 0.24447821, 0.44244713, 0.5555287, 0.72162366, 0.6451375, 0.72162366, 0.6451375, 0.7148789, 0.3469143, 0.45546925, 0.5395904, 0.45546925, 0.5395904, 0.7020831, 0.62807125, 0.6732891, 0.33909014, 0.4699702, 0.648818, 0.7066812, 0.5573441, 0.51776713, 0.50491005, 0.4984698, 0.5964323, 0.584513, 0.41421387, 0.7965971, 0.17838548, 0.49800646, 0.5605282, 0.6829182, 0.6423919, 0.68173635, 0.44958422, 0.5904122, 0.53526896, 0.47146308, 0.44959775, 0.59512526, 0.62631446, 0.4892098, 0.52895814, 0.34231848, 0.52426946, 0.34565088, 0.56260693, 0.6047245, 0.45708624, 0.36293086, 0.5261409, 0.6436668, 0.5041494, 0.6544861, 0.52058, 0.64842576, 0.6465696, 0.38004133, 0.5761006, 0.38600275, 0.522972, 0.4892098, 0.52895814, 0.6393283, 0.44173482, 0.39299518, 0.40813962, 0.39471546, 0.56130564, 0.538853, 0.5306338, 0.4972335, 0.43204603, 0.5435213, 0.43335184, 0.5445134, 0.49403867, 0.6320203, 0.64852226, 0.62570095, 0.42572713, 0.3980729, 0.47170863, 0.3980729, 0.47170863, 0.4183546, 0.40913516, 0.7348106, 0.64237857, 0.73428965, 0.6267415, 0.7272213, 0.457885, 0.726572, 0.47750783, 0.72518176, 0.52720505, 0.5706611, 0.53584224, 0.5706611, 0.53584224, 0.72492886, 0.5428516, 0.57300436, 0.4370054, 0.68539196, 0.6482775, 0.4984698, 0.5964323, 0.36519197, 0.61657673, 0.36519197, 0.61657673, 0.6837442, 0.58889204, 0.505615, 0.61114347, 0.44397786, 0.6068878, 0.5375365, 0.6046104, 0.30555788, 0.58341056, 0.31337965, 0.58188885, 0.31589228, 0.6260323, 0.6051046, 0.53677493, 0.46389243, 0.6204676, 0.51534283, 0.626351, 0.6665707, 0.38101736, 0.46389243, 0.6204676, 0.89681, 0.78994536, 0.8954525, 0.20112908, 0.5176546, 0.55344677, 0.40819302, 0.6106456, 0.5526049, 0.5909981, 0.4119644, 0.48767734, 0.5176546, 0.55344677, 0.62159115, 0.49399585, 0.63007015, 0.35594368, 0.49061233, 0.6238744, 0.62159115, 0.49399585, 0.6381992, 0.62495136, 0.6381992, 0.62495136, 0.6194724, 0.5556205, 0.6406758, 0.60641193, 0.427843, 0.5848331, 0.64821196, 0.58266217, 0.51534283, 0.626351, 0.5744214, 0.56159735, 0.66779506, 0.5638941, 0.28435442, 0.51196414, 0.6455166, 0.36879638, 0.6229328, 0.5792376, 0.30155215, 0.48462903, 0.6531595, 0.53735745, 0.6455166, 0.36879638, 0.6455166, 0.36879638, 0.6531595, 0.53735745, 0.6697502, 0.53458434, 0.609689, 0.54835695, 0.44523582, 0.36115724, 0.6675432, 0.6013193, 0.6809117, 0.53156674, 0.5896957, 0.38302892, 0.5896957, 0.38302892, 0.58489025, 0.36505872, 0.33617482, 0.3691568, 0.5950458, 0.3677 ...

# %%
print(len(images1))
label_values1 = np.array(label_values).reshape(-1, 8)
print(len(label_values1))
# Out:
# 4165
# 4165

# %%
# save to csv
import pandas as pd
# merge the images and label_values
df = pd.DataFrame(images1)
df1 = pd.DataFrame(label_values1, columns=['top_left_x', 'top_left_y', 'top_right_x', 'top_right_y', 'bottom_left_x', 'bottom_left_y', 'bottom_right_x', 'bottom_right_y'])
df = pd.concat([df, df1], axis=1)
df.to_csv('Datasets/images_with_labels.csv', index=False)

# %%
images = np.array(images).reshape(-1, 200)
# write label_values into one dimensional array
label_values = np.array(label_values).reshape(-1, 8)

images = images / 255

# %%
images.shape, label_values.shape
# Out:
# ((4165, 256, 256), (4165, 8))

# %%
np.save('Datasets/images_norm.npy', images)
np.save('Datasets/label_values_norm.npy', label_values)

# %%
# load the half of the dataset from a file
#images = np.load('Datasets/images.npy')[:int(len(images)/4)]
#label_values = np.load('Datasets/label_values.npy')[:int(len(label_values)/4)]

images = np.load('Datasets/images_norm.npy')
label_values = np.load('Datasets/label_values_norm.npy')
splited_into_train_test = False

# %%
# normalize the label values
# remove bottom left and top right corners (save only 0,1,6,7 indexes)
# label_values = label_values[:, [0, 1, 6, 7]]

# %%
# compress the dataset by changing the types of the values
images = images.astype('bool')
label_values = label_values.astype('float16')

# %%
images.shape, label_values.shape
# Out:
# ((4165, 256, 256), (4165, 8))

# %%
# split the dataset into training and testing
from sklearn.model_selection import train_test_split
splited_into_train_test = True
X_train, X_test, y_train, y_test = train_test_split(images, label_values, test_size=0.3, random_state=42)

# %%
from tensorflow import convert_to_tensor
if splited_into_train_test:
    X_test = convert_to_tensor(X_test)
    y_test = convert_to_tensor(y_test)
else:
    images = convert_to_tensor(images)
    label_values = convert_to_tensor(label_values)

# %%
#create a model with self-attention layer
from tensorflow.keras.layers import Layer
from tensorflow.keras import initializers, regularizers, constraints
from tensorflow.keras import activations
from tensorflow.keras import Input
from tensorflow.keras import Model

class SelfAttention(Layer):
    def __init__(self, units=32, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)
        self.units = units

    def build(self, input_shape):
        self.W = self.add_weight(name="W", shape=(input_shape[-1], self.units), initializer="random_normal", trainable=True)
        self.V = self.add_weight(name="V", shape=(self.units, 1), initializer="random_normal", trainable=True)
        self.U = self.add_weight(name="U", shape=(input_shape[-1], self.units), initializer="random_normal", trainable=True)
        self.b = self.add_weight(name="b", shape=(self.units,), initializer="random_normal", trainable=True)
        super(SelfAttention, self).build(input_shape)

    def call(self, inputs):
        # calculate the attention weights
        u = K.tanh(K.dot(inputs, self.W) + self.b)
        u = K.dot(u, self.V)
        u = K.softmax(u, axis=1)
        # calculate the context vector
        c = K.dot(inputs, self.U)
        c = K.batch_dot(u, c, axes=[1, 1])
        return c

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[-1])

    def get_config(self):
        return super(SelfAttention, self).get_config()
    
    @classmethod
    def from_config(cls, config):
        return cls(**config)
    
    def get_config(self):
        return super().get_config()

# %%
#initialize the model with the self-attention layer
model = Sequential()
model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(256, 256, 1), padding="same"))
model.add(Conv2D(64, (3, 3), activation="relu", padding="same"))
model.add(SelfAttention(64))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(8, activation='linear'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=[RootMeanSquaredError()])
if splited_into_train_test:
    model.fit(X_train, y_train, epochs=15, batch_size=32, validation_data=(X_test, y_test))
else:
    model.fit(images, label_values, epochs=15, batch_size=32)
# Out:
# WARNING:tensorflow:From d:\Python\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/15
# WARNING:tensorflow:From d:\Python\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 92/92 [==============================] - 515s 5s/step - loss: 167.3818 - root_mean_squared_error: 12.9376 - val_loss: 0.4136 - val_root_mean_squared_error: 0.6431
# Epoch 2/15
# 92/92 [==============================] - 600s 7s/step - loss: 0.4122 - root_mean_squared_error: 0.6421 - val_loss: 0.4055 - val_root_mean_squared_error: 0.6368
# Epoch 3/15
# 92/92 [==============================] - 566s 6s/step - loss: 0.4029 - root_mean_squared_error: 0.6347 - val_loss: 0.3951 - val_root_mean_squared_error: 0.6285
# Epoch 4/15
# 92/92 [==============================] - 550s 6s/step - loss: 0.3916 - root_mean_squared_error: 0.6258 - val_loss: 0.3829 - val_root_mean_squared_error: 0.6188
# Epoch 5/15
# 92/92 [==============================] - 546s 6s/step - loss: 0.3788 - root_mean_squared_error: 0.6154 - val_loss: 0.3695 - val_root_mean_squared_error: 0.6079
# Epoch 6/15
# 56/92 [=================>............] - ETA: 3:21 - loss: 0.3677 - root_mean_squared_error: 0.6064
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 12
#      10 model.compile(loss='mean_squared_error', optimizer='adam', metrics=[RootMeanSquaredError()])
#      11 if splited_into_train_test:
# ---> 12     model.fit(X_train, y_train, epochs=15, batch_size=32, validation_data=(X_test, y_test))
#      13 else:
#      14     model.fit(images, label_values, epochs=15, batch_size=32)
#
# File d:\Python\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Python\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File d:\Python\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File d:\Python\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Implement the CNN regression model for predicting the four points (x,y) for cropping the 256x256 image
# MaxPooling2D((2,2)) # AveragePooling2D((2,2)) # Lambda(lambda x: l2_norm(x))

model = Sequential()
model.add(Conv2D(32, (5, 5), activation="relu", input_shape=(256, 256, 1), padding="same", strides=(2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(32, (5, 5), activation="relu", padding="same", strides=(2, 2)))
model.add(BatchNormalization())
model.add(AveragePooling2D((2, 2), strides=2, padding='valid'))
model.add(Dropout(0.75))
model.add(Conv2D(64, (3, 3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(AveragePooling2D((2, 2), strides=2, padding='valid'))
model.add(Dropout(0.75))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.75))
model.add(Dense(8, activation='linear'))


model.compile(loss='mean_squared_error', optimizer='adam', metrics=[RootMeanSquaredError()])
if splited_into_train_test:
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
else:
    model.fit(images, label_values, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 10s 67ms/step - loss: 5.7180 - root_mean_squared_error: 2.3912 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2332
# Epoch 2/100
# 92/92 [==============================] - 6s 60ms/step - loss: 3.0674 - root_mean_squared_error: 1.7514 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1906
# Epoch 3/100
# 92/92 [==============================] - 6s 60ms/step - loss: 2.0705 - root_mean_squared_error: 1.4389 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1988
# Epoch 4/100
# 92/92 [==============================] - 6s 61ms/step - loss: 1.3147 - root_mean_squared_error: 1.1466 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2041
# Epoch 5/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.8450 - root_mean_squared_error: 0.9193 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# Epoch 6/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.6060 - root_mean_squared_error: 0.7785 - val_loss: 0.0550 - val_root_mean_squared_error: 0.2346
# Epoch 7/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.4163 - root_mean_squared_error: 0.6452 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 8/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.2958 - root_mean_squared_error: 0.5439 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1643
# Epoch 9/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1854 - root_mean_squared_error: 0.4306 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283
# Epoch 10/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1363 - root_mean_squared_error: 0.3692 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468
# Epoch 11/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1006 - root_mean_squared_error: 0.3171 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1335
# Epoch 12/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0774 - root_mean_squared_error: 0.2781 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 13/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0582 - root_mean_squared_error: 0.2413 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# Epoch 14/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0414 - root_mean_squared_error: 0.2036 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 15/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0349 - root_mean_squared_error: 0.1868 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 16/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0255 - root_mean_squared_error: 0.1598 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 17/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0218 - root_mean_squared_error: 0.1478 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 18/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 19/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 20/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0139 - root_mean_squared_error: 0.1177 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 21/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 22/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 23/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 24/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 25/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0840
# Epoch 26/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0089 - root_mean_squared_error: 0.0942 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 27/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 28/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 29/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 30/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0778
# Epoch 31/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0071 - root_mean_squared_error: 0.0842 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 32/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 33/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 34/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 35/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 36/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 37/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 38/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0070 - root_mean_squared_error: 0.0836 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 39/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 40/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 41/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 42/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 43/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 44/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 45/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 46/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0742
# Epoch 47/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 48/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 49/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0290 - root_mean_squared_error: 0.1702 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 50/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0388 - root_mean_squared_error: 0.1969 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 51/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0290 - root_mean_squared_error: 0.1703 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 52/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0214 - root_mean_squared_error: 0.1464 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1151
# Epoch 53/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 54/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 55/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0344 - root_mean_squared_error: 0.1855 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 56/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0300 - root_mean_squared_error: 0.1733 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1404
# Epoch 57/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0312 - root_mean_squared_error: 0.1767 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 58/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 59/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 60/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 61/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 62/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 63/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 64/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 65/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 66/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 67/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 68/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 69/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 70/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 71/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 72/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0908
# Epoch 73/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1333
# Epoch 74/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 75/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 76/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 77/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1401
# Epoch 78/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1168
# Epoch 79/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1023
# Epoch 80/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 81/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0106 - root_mean_squared_error: 0.1032 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 82/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 83/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 84/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 85/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 86/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 87/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098
# Epoch 88/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1586
# Epoch 89/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 90/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 91/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 92/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0972
# Epoch 93/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 94/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 95/100
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 96/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 97/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 98/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 99/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0095 - root_mean_squared_error: 0.0976 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 100/100
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834

# %%
# save the model
from tensorflow.keras.models import save_model
save_model(model, 'CNN_cropping_model_4.keras', save_format='h5')

# %% [markdown]
# v2 - preproces: exp_interp=True
#
# v3 - preproces: exp_interp=False, GPU

# %%
from local_package.ConvNN import preproces
from tensorflow.keras.models import load_model
loaded_model = load_model('CNN_cropping_model_4.keras', custom_objects={'SelfAttention': SelfAttention})

# %%
#test the model
img_path = './scrapped_images1/8_4.jpg'
image = cv2.imread(img_path)
preprocessed_image = preproces(img_path)
predicted_points = loaded_model.predict((np.array([preprocessed_image]) / 255).astype('bool'))
#predicted_points = np.where(predicted_points < 0.5, predicted_points*2, (predicted_points-0.5)*2)
#predicted_points = np.array([0,0,1,0,0,1,1,1])
predicted_points = predicted_points.reshape(-1, 2)
print(predicted_points)
# denormalize the points
'''
print(predicted_points)

left_top = [predicted_points[0][0] / 2, predicted_points[0][1] / 2]
right_top = [(predicted_points[1][0]/2)+0.5, predicted_points[1][1] / 2]
left_bottom = [predicted_points[2][0] / 2, (predicted_points[2][1]/2)+0.5]
right_bottom = [(predicted_points[3][0]/2)+0.5, (predicted_points[3][1]/2)+0.5]


predicted_points = np.array([left_top, right_top, left_bottom, right_bottom])
print(predicted_points)
predicted_points[:, 0] *= image.shape[1]
predicted_points[:, 1] *= image.shape[0]
predicted_points = predicted_points.astype(np.int32)
'''
if max(image.shape) > 1000:
    image = cv2.resize(image, (int(image.shape[1]*0.25), int(image.shape[0]*0.25)))
#predicted_points[:, 0] /= 255
predicted_points[:, 0] *= image.shape[1]
#predicted_points[:, 1] /= 255
predicted_points[:, 1] *= image.shape[0]
predicted_points = predicted_points.astype(np.int32)
print(predicted_points)
print(image.shape)

preprocessed_image = cv2.cvtColor(preprocessed_image, cv2.COLOR_GRAY2BGR)
preprocessed_image = cv2.resize(preprocessed_image, (image.shape[1], image.shape[0]))
# draw the points on the image
for i, point in enumerate(predicted_points):
    cv2.circle(image, (point[0], point[1]), 5, (0, 0, 255), -1)
    cv2.circle(preprocessed_image, (point[0], point[1]), 5, (0, 0, 255), -1)


cv2.imshow('test_image', image)
cv2.imshow('prerocessed_image', preprocessed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [[0.29192832 0.23424691]
#  [0.73803234 0.23270541]
#  [0.28690824 0.73582864]
#  [0.7333375  0.7354136 ]]
# [[175 140]
#  [442 139]
#  [172 441]
#  [440 441]]
# (600, 600, 3)

# %%
image = cv2.imread(img_path)
predicted_points = model.predict(np.array([preproces(img_path, expodential_interpolation=False)]) / 255.0)
predicted_points = predicted_points.reshape(-1, 2)
print(predicted_points)
# denormalize the x points
predicted_points[:, 0] /= 255.0
predicted_points[:, 0] *= image.shape[1]
# denormalize the y points
predicted_points[:, 1] /= 255.0
predicted_points[:, 1] *= image.shape[0]
# convert the points to integer
predicted_points = predicted_points.astype(np.int32)

print(predicted_points)
# draw the points on the image
for point in predicted_points:
    cv2.circle(image, (point[0], point[1]), 5, (0, 0, 255), -1)

# # trim the image to the edges
# image = image[predicted_points[0][1]:predicted_points[3][1], predicted_points[0][0]:predicted_points[1][0]]
# cv2.imshow('test_image', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# top_left, top_right, bottom_left, bottom_right = trim_to_edges(image,'20_')
# # move points from the center by a margin
# # margin = 60
# # top_left = (top_left[0] + margin, top_left[1] + margin)
# # top_right = (top_right[0] - margin, top_right[1] + margin)
# # bottom_left = (bottom_left[0] + margin, bottom_left[1] - margin)
# # bottom_right = (bottom_right[0] - margin, bottom_right[1] - margin)

# image = crop_with_perspective(image, top_left, top_right, bottom_left, bottom_right)

# # return the image to the original aspect ratio
# max_height = predicted_points[3][1] - predicted_points[0][1]
# max_width = predicted_points[1][0] - predicted_points[0][0]
# image = cv2.resize(image, (0,0), fx=1, fy=max_height/max_width if max_height > max_width else max_width/max_height)
cv2.imshow('test_image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 568ms/step
# [[0.07005253 0.05350221]
#  [0.8757026  0.0530272 ]
#  [0.07094659 0.89496064]
#  [0.871609   0.8950962 ]]
# [[0 0]
#  [2 0]
#  [0 2]
#  [2 2]]

# %%
img_path = './scrapped_images1/8_12.jpg'
import time
# count the time for preprocessing the image
#preprocessed_image = preproces(image_path, expodential_interpolation=False)
source_image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
time_start = time.time()
# # remove jpg noise
# image = cv2.Canny(image, 8, 32, L2gradient=False)
# image = cv2.fastNlMeansDenoising(source_image, None, 10, 7, 21)
# #image = cv2.GaussianBlur(image,(3,3),20)
# # cv2.imshow('preprocessed_image', image)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# se = cv2.getStructuringElement(cv2.MORPH_RECT, (8,8))
# bg = cv2.morphologyEx(image, cv2.MORPH_DILATE, se)
# image = cv2.divide(image, bg, scale=255)
#image = cv2.equalizeHist(image)
# cv2.imshow('preprocessed_image', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
#image = cv2.threshold(source_image, 0, 255, cv2.THRESH_OTSU)[1]
#image = cv2.GaussianBlur(image,(5,5),1)
# make one more canny edge detection with different parameters
image = source_image
image = cv2.equalizeHist(image)
image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)
image = cv2.Canny(image, 8, 32, L2gradient=False)
image2 = cv2.Canny(source_image, 50, 150, L2gradient=False)

#combine the two edge detection results
image = cv2.bitwise_or(image, image2)
# new_image = np.zeros((256, 256), dtype=np.uint8)
# for x in range(128):
#     for y in range(128):
#         #write the pixels with quad growth so for the 128 pixel was the same as len(image)/2 pixels
#         half_height = len(image)//2
#         half_width = len(image[0])//2
#         a_x = (half_height*11.25-half_height*8)/(54720)
#         b_x = half_height/180-a_x*90
#         old_x = int(a_x*x**2+b_x*x)
#         a_y = (half_width*11.25-half_width*8)/(54720)
#         b_y = half_width/180-a_y*90
#         old_y = int(a_y*y**2+b_y*y)

#         # calculate the new pixels color using interpolation
#         new_image[x][y] = image[old_x][old_y]
#         new_image[255-x][255-y] = image[len(image)-1-old_x][len(image[0])-1-old_y]
#         new_image[255-x][y] = image[len(image)-1-old_x][old_y]
#         new_image[x][255-y] = image[old_x][len(image[0])-1-old_y]
# image = new_image
# lines = cv2.HoughLinesP(image, 1, np.pi/180, threshold=1, minLineLength=1, maxLineGap=100)
# canvas_edges = []
# for line in lines:
#     x1, y1, x2, y2 = line[0]
#     canvas_edges.append((x1, y1))
#     canvas_edges.append((x2, y2))
# x, y, w, h = cv2.boundingRect(np.array(canvas_edges))
# padding = 40
# image = cv2.rectangle(image, (x+padding, y+padding), (x+w-padding, y+h-padding), (0,0,0), -1)
time = time.time() - time_start
print(time)
cv2.imshow('preprocessed_image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0.154557466506958

# %%
image = crop_with_perspective(image, predicted_points[0], predicted_points[1], predicted_points[2], predicted_points[3])

# return the image to the original aspect ratio
max_height = predicted_points[3][1] - predicted_points[0][1]
max_width = predicted_points[1][0] - predicted_points[0][0]
image = cv2.resize(image, (0,0), fx=1, fy=max_height/max_width if max_height > max_width else max_width/max_height)
#image = cv2.resize(image, (0,0), fx=0.5, fy=0.5)
cv2.imshow('image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Cropping test

# %%
from local_package.Cropping import trim_to_edges, crop_with_perspective

# %%
test_image_path = './scrapped_images1/19_12.jpg'
test_image = cv2.imread(test_image_path)
if max(test_image.shape) > 1000:
    test_image = cv2.resize(test_image, (0,0), fx=0.25, fy=0.25)
points = trim_to_edges(test_image, os.path.basename(test_image_path))
for point in points:
    cv2.circle(test_image, (point[0], point[1]), 5, (0, 0, 255), -1)
test_image = crop_with_perspective(test_image, points[0], points[1], points[2], points[3])
cv2.imshow('test_image', test_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def preproces_(img_path, expodential_interpolation=True):
    source_image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if not expodential_interpolation:
        source_image = cv2.resize(source_image, (256, 256))

    #create a checker texture
    checker = np.zeros((256, 256), dtype=np.uint8)
    for x in range(256):
        for y in range(256):
            if (x//16+y//16)%2==0:
                checker[x][y] = 255
    image = checker
    image = source_image

    # image = cv2.equalizeHist(source_image)
    # image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)
    # image = cv2.Canny(image, 8, 32, L2gradient=False)
    # image2 = cv2.Canny(source_image, 50, 150, L2gradient=False)
    # #combine the two edge detection results
    # image = cv2.bitwise_or(image, image2)
    
    #write into a new 256x256 image pixels from the original image starting from the edges on the image
    if expodential_interpolation:
        new_image = np.zeros((256, 256), dtype=np.uint8)
        for x in range(128):
            for y in range(128):
                #write the pixels with quad growth so for the 128 pixel was the same as len(image)/2 pixels
                half_height = len(image)//2
                half_width = len(image[0])//2
                a_x = (half_height*11.25-half_height*8)/(54720)
                b_x = half_height/180-a_x*90
                old_x = int(a_x*x**2+b_x*x)
                a_y = (half_width*11.25-half_width*8)/(54720)
                b_y = half_width/180-a_y*90
                old_y = int(a_y*y**2+b_y*y)

                # calculate the new pixels color using interpolation
                new_image[x][y] = image[old_x][old_y]
                new_image[255-x][255-y] = image[len(image)-1-old_x][len(image[0])-1-old_y]
                new_image[255-x][y] = image[len(image)-1-old_x][old_y]
                new_image[x][255-y] = image[old_x][len(image[0])-1-old_y]
        image = new_image
    return image

# %%
orig_image = cv2.imread('./scrapped_images1/19_12.jpg')
image = preproces_("./scrapped_images1/19_12.jpg", expodential_interpolation=True)
image = cv2.resize(image, (0,0), fx=2, fy=2)
if max(orig_image.shape) > 1000:
    orig_image = cv2.resize(orig_image, (0,0), fx=0.25, fy=0.25)
cv2.imshow('image', image)
cv2.imshow('orig_image', orig_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
IMG_RESOLUTION = (256, 256)
def preproces(img_path, show=False):
    source_image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    # create a checker texture
    # checker = np.zeros(IMG_RESOLUTION, dtype=np.uint8)
    # for x in range(IMG_RESOLUTION[0]):
    #     for y in range(IMG_RESOLUTION[1]):
    #         if (x//16+y//16)%2==0:
    #             checker[x][y] = 255
    # source_image = checker

    image = cv2.equalizeHist(source_image)

    #write into a new 256x256 image pixels from the original image starting from the edges on the image
    new_image = np.zeros((256, 256), dtype=np.uint8)
    for x in range(128):
        for y in range(128):
            #write the pixels with quad growth so for the 128 pixel was the same as len(image)/2 pixels
            half_height = len(image)//2
            half_width = len(image[0])//2
            a_x = (half_height*11.25-half_height*8)/(54720)
            b_x = half_height/180-a_x*90
            old_x = int(a_x*x**2+b_x*x)
            a_y = (half_width*11.25-half_width*8)/(54720)
            b_y = half_width/180-a_y*90
            old_y = int(a_y*y**2+b_y*y)

            # calculate the new pixels color using interpolation
            new_image[x][y] = image[old_x][old_y]
            new_image[255-x][255-y] = image[len(image)-1-old_x][len(image[0])-1-old_y]
            new_image[255-x][y] = image[len(image)-1-old_x][old_y]
            new_image[x][255-y] = image[old_x][len(image[0])-1-old_y]
    image = new_image
    #show image
    if show:
        cv2.imshow("image", image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

    return image

# %%
img_path = './scrapped_images1/19_29.jpg'
image = preproces(img_path,True)

# %%
img = cv2.imread(img_path)
img = cv2.resize(img, (0,0), fx=0.25, fy=0.25)
cv2.imshow('image', img)
cv2.waitKey(0)
# Out:
# -1
